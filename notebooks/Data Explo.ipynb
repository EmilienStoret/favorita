# %%
import pandas as pd
path = '/home/emilien/code/EmilienStoret/favorita/.gitignore/store-sales-time-series-forecasting/train.csv'

l=['train', 'holidays_events', 'oil', 'stores', 'transactions', 'test']

d={'dataframe':[] ,'columns': [], 'is_na':[], 'is_duplicated': []}

for i in l: 
    path = '/home/emilien/code/EmilienStoret/favorita/.gitignore/store-sales-time-series-forecasting/'+str(i)+'.csv'
    globals()['df_'+str(i)]=pd.DataFrame()
    globals()['df_'+str(i)] = pd.read_csv(path)

for df in l:
    print(df)
    for col in globals()['df_'+str(df)].columns:
        df_loop = globals()['df_'+str(df)]
        k = df_loop[col].isna().sum()
        print(f'{col}: {k}')
        d['dataframe'].append(df)
        d['columns'].append(col)
        d['is_na'].append(k)
# Out:
# train
# id: 0
# date: 0
# store_nbr: 0
# family: 0
# sales: 0
# onpromotion: 0
# holidays_events
# date: 0
# type: 0
# locale: 0
# locale_name: 0
# description: 0
# transferred: 0
# oil
# date: 0
# dcoilwtico: 43
# stores
# store_nbr: 0
# city: 0
# state: 0
# type: 0
# cluster: 0
# transactions
# date: 0
# store_nbr: 0
# transactions: 0
# test
# id: 0
# date: 0
# store_nbr: 0
# family: 0
# onpromotion: 0

# %%
for df in l:
    k = globals()['df_'+str(df)].duplicated().sum()
    print(f'{df}: {k}')
# Out:
# train: 0
# holidays_events: 0
# oil: 0
# stores: 0
# transactions: 0

# %%
df_test
# Out:
#             id        date  store_nbr                      family  onpromotion
# 0      3000888  2017-08-16          1                  AUTOMOTIVE            0
# 1      3000889  2017-08-16          1                   BABY CARE            0
# 2      3000890  2017-08-16          1                      BEAUTY            2
# 3      3000891  2017-08-16          1                   BEVERAGES           20
# 4      3000892  2017-08-16          1                       BOOKS            0
# ...        ...         ...        ...                         ...          ...
# 28507  3029395  2017-08-31          9                     POULTRY            1
# 28508  3029396  2017-08-31          9              PREPARED FOODS            0
# 28509  3029397  2017-08-31          9                     PRODUCE            1
# 28510  3029398  2017-08-31          9  SCHOOL AND OFFICE SUPPLIES            9
# 28511  3029399  2017-08-31          9                     SEAFOOD            0
#
# ...

# %%
df_stores
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...
